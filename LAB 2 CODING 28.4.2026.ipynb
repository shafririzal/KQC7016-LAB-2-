# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("WorldEnergy.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 23190       Zimbabwe  2020      ZWE  15526837.0  2.317871e+10
# 23191       Zimbabwe  2021      ZWE  15797165.0  2.514009e+10
# 23192       Zimbabwe  2022      ZWE  16069010.0  2.590159e+10
# 23193       Zimbabwe  2023      ZWE  16340778.0           NaN
# 23194       Zimbabwe  2024      ZWE  16634317.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 23190                      NaN                      0.0
# 23191                      NaN                      0.0
# 23192                      NaN                      0.0
# 23193                      NaN                      0.0
# 23194                      NaN                      0.0
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                          NaN                  NaN                      NaN
# 1                          NaN                  NaN                      NaN
# 2                          NaN                  NaN                      NaN
# 3                          NaN                  NaN                      NaN
# 4                          NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 23190                      0.0                  0.0                    6.440
# 23191                      0.0                  0.0                    6.963
# 23192                      0.0                  0.0                    6.845
# 23193                      0.0                  0.0                    7.344
# 23194                      0.0                  0.0                      NaN
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000                 NaN                   NaN
# 1      ...             0.000                 NaN                   NaN
# 2      ...             0.000                 NaN                   NaN
# 3      ...             0.000                 NaN                   NaN
# 4      ...             0.000                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 23190  ...             0.298                 NaN                   NaN
# 23191  ...             0.233                 NaN                   NaN
# 23192  ...             0.336                 NaN                   NaN
# 23193  ...             0.361                 NaN                   NaN
# 23194  ...               NaN                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 23190                   NaN               NaN                   0.0
# 23191                   NaN               NaN                   0.0
# 23192                   NaN               NaN                   0.0
# 23193                   NaN               NaN                   0.0
# 23194                   NaN               NaN                   NaN
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                   0.0                     NaN              0.0
# 1                   0.0                     NaN              0.0
# 2                   0.0                     NaN              0.0
# 3                   0.0                     NaN              0.0
# 4                   0.0                     NaN              0.0
# ...                 ...                     ...              ...
# 23190               0.0                     NaN              0.0
# 23191               0.0                     NaN              0.0
# 23192               0.0                     NaN              0.0
# 23193               0.0                     NaN              0.0
# 23194               NaN                     NaN              NaN
#
#        wind_share_energy
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 23190                NaN
# 23191                NaN
# 23192                NaN
# 23193                NaN
# 23194                NaN
#
# [23195 rows x 130 columns]>

# %%
data.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=130)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23195 entries, 0 to 23194
# Columns: 130 entries, country to wind_share_energy
# dtypes: float64(127), int64(1), object(2)
# memory usage: 23.0+ MB

# %%
data.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  23195.000000  1.872900e+04  1.178000e+04              2070.000000
# mean    1975.859280  1.010849e+08  4.257565e+11                43.478804
# std       35.207901  4.606079e+08  3.507870e+12               286.672317
# min     1900.000000  1.733000e+03  1.642060e+08              -100.000000
# 25%     1949.000000  1.596265e+06  1.426394e+10                -0.968000
# 50%     1985.000000  6.875000e+06  4.357680e+10                 6.695500
# 75%     2005.000000  2.531192e+07  1.830576e+11                23.320750
# max     2024.000000  8.161972e+09  1.301126e+14              6373.062000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              7903.000000              6338.000000          8057.000000
# mean                  1.054261                55.157858            15.092054
# std                   6.641947               180.665240            75.942529
# min                 -59.084000                 0.000000             0.000000
# 25%                   0.000000                 0.000000             0.000000
# 50%                   0.000000                 0.000000             0.000000
# 75%                   0.000000                 0.506750             0.062000
# max                 144.290000              2587.921000          1366.878000
#
#        biofuel_elec_per_capita  biofuel_electricity  biofuel_share_elec  ...  \
# count              5753.000000          6063.000000         6040.000000  ...
# mean                 69.409590            12.252558            1.939152  ...
# std                 199.403432            52.276644            5.339924  ...
# min                   0.000000             0.000000            0.000000  ...
# 25%                   0.000000             0.000000            0.000000  ...
# 50%                   0.793000             0.020000            0.148500  ...
# 75%                  42.905000             0.860000            1.601000  ...
# max                2450.813000           712.160000           77.586000  ...
#
#        solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# count       7940.000000         6379.000000           2798.000000
# mean           0.902081            0.219802            290.408294
# std            2.775481            0.766125           6070.498582
# min            0.000000            0.000000           -100.000000
# 25%            0.000000            0.000000              2.329000
# 50%            0.000000            0.000000             18.349500
# 75%            0.200000            0.006000             45.210750
# max           50.000000            9.881000         242384.859000
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# count           6293.000000       6405.000000           8301.000000
# mean               6.021235         48.691257             63.651510
# std               34.260028        281.755752            259.959746
# min              -46.535000          0.000000              0.000000
# 25%                0.000000          0.000000              0.000000
# 50%                0.000000          0.000000              0.000000
# 75%                0.096000          0.916000              1.695000
# max              642.617000       6124.465000           3850.312000
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# count       9871.000000             5145.000000      7868.000000
# mean          18.589892              214.960358         1.521953
# std          114.342308              733.884486         4.619313
# min            0.000000                0.000000         0.000000
# 25%            0.000000                0.000000         0.000000
# 50%            0.000000                0.000000         0.000000
# 75%            0.090000               25.914000         0.473250
# max         2497.250000             9315.340000        57.913000
#
#        wind_share_energy
# count        6379.000000
# mean            0.518141
# std             1.722172
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.074500
# max            26.085000
#
# [8 rows x 128 columns]

# %%
''' deleting redundant columns 
Renaming the columns
Dropping duplicates
Cleaning indvidual columns 
Remove the NaN Values from the dataset 
Check for some more transformation '''
# Out:
# ' deleting redundant columns \nRenaming the columns\nDropping duplicates\nCleaning indvidual columns \nRemove the NaN Values from the dataset \nCheck for some more transformation '

# %%
data.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=130)

# %%
columns_to_keep=['country','year','population','gdp','biofuel_consumption','coal_consumption', 'fossil_fuel_consumption', 'gas_consumption', 'hydro_consumption', 'nuclear_consumption', 'oil_consumption', 'primary_energy_consumption', 'solar_consumption', 'wind_consumption']

# %%
len(columns_to_keep)
# Out:
# 14

# %% [markdown]
# # 1st Method, Filtering Data

# %%
data[columns_to_keep]
# Out:
#              country  year  population           gdp  biofuel_consumption  \
# 0      ASEAN (Ember)  2000         NaN           NaN                  NaN
# 1      ASEAN (Ember)  2001         NaN           NaN                  NaN
# 2      ASEAN (Ember)  2002         NaN           NaN                  NaN
# 3      ASEAN (Ember)  2003         NaN           NaN                  NaN
# 4      ASEAN (Ember)  2004         NaN           NaN                  NaN
# ...              ...   ...         ...           ...                  ...
# 23190       Zimbabwe  2020  15526837.0  2.317871e+10                  0.0
# 23191       Zimbabwe  2021  15797165.0  2.514009e+10                  0.0
# 23192       Zimbabwe  2022  16069010.0  2.590159e+10                  0.0
# 23193       Zimbabwe  2023  16340778.0           NaN                  0.0
# 23194       Zimbabwe  2024  16634317.0           NaN                  0.0
#
#        coal_consumption  fossil_fuel_consumption  gas_consumption  \
# 0                   NaN                      NaN              NaN
# 1                   NaN                      NaN              NaN
# 2                   NaN                      NaN              NaN
# 3                   NaN                      NaN              NaN
# 4                   NaN                      NaN              NaN
# ...                 ...                      ...              ...
# 23190               NaN                      NaN              NaN
# 23191               NaN                      NaN              NaN
# 23192               NaN                      NaN              NaN
# 23193               NaN                      NaN              NaN
# 23194               NaN                      NaN              NaN
#
#        hydro_consumption  nuclear_consumption  oil_consumption  \
# 0                    NaN                  NaN              NaN
# 1                    NaN                  NaN              NaN
# 2                    NaN                  NaN              NaN
# 3                    NaN                  NaN              NaN
# 4                    NaN                  NaN              NaN
# ...                  ...                  ...              ...
# 23190                NaN                  0.0              NaN
# 23191                NaN                  0.0              NaN
# 23192                NaN                  0.0              NaN
# 23193                NaN                  0.0              NaN
# 23194                NaN                  0.0              NaN
#
#        primary_energy_consumption  solar_consumption  wind_consumption
# 0                             NaN                NaN               NaN
# 1                             NaN                NaN               NaN
# 2                             NaN                NaN               NaN
# 3                             NaN                NaN               NaN
# 4                             NaN                NaN               NaN
# ...                           ...                ...               ...
# 23190                      33.586                NaN               NaN
# 23191                      37.636                NaN               NaN
# 23192                      58.380                NaN               NaN
# 23193                      51.986                NaN               NaN
# 23194                         NaN                NaN               NaN
#
# [23195 rows x 14 columns]

# %%
df=data[columns_to_keep]

# %%
df_Sweden=df.loc[df['country'].isin(['Sweden']), columns_to_keep]
df_Sweden.rename(columns=str.upper, inplace=True)

# %%
print(df_Sweden)
# Out:
#       COUNTRY  YEAR  POPULATION           GDP  BIOFUEL_CONSUMPTION  \
# 19733  Sweden  1900   5123503.0  1.698844e+10                  NaN
# 19734  Sweden  1901   5157047.0  1.756134e+10                  NaN
# 19735  Sweden  1902   5190268.0  1.743869e+10                  NaN
# 19736  Sweden  1903   5223160.0  1.843819e+10                  NaN
# 19737  Sweden  1904   5256260.0  1.886236e+10                  NaN
# ...       ...   ...         ...           ...                  ...
# 19853  Sweden  2020  10353627.0  4.568853e+11               12.787
# 19854  Sweden  2021  10416075.0  4.814924e+11               14.206
# 19855  Sweden  2022  10487289.0  4.942145e+11               17.427
# 19856  Sweden  2023  10551441.0           NaN               15.620
# 19857  Sweden  2024  10606934.0           NaN                4.235
#
#        COAL_CONSUMPTION  FOSSIL_FUEL_CONSUMPTION  GAS_CONSUMPTION  \
# 19733               NaN                      NaN              NaN
# 19734               NaN                      NaN              NaN
# 19735               NaN                      NaN              NaN
# 19736               NaN                      NaN              NaN
# 19737               NaN                      NaN              NaN
# ...                 ...                      ...              ...
# 19853            18.612                  162.972            9.909
# 19854            18.925                  176.748           10.628
# 19855            18.445                  159.071            7.998
# 19856            18.647                  157.322            8.774
# 19857            18.755                  164.165            9.502
#
#        HYDRO_CONSUMPTION  NUCLEAR_CONSUMPTION  OIL_CONSUMPTION  \
# 19733                NaN                  NaN              NaN
# 19734                NaN                  NaN              NaN
# 19735                NaN                  NaN              NaN
# 19736                NaN                  NaN              NaN
# 19737                NaN                  NaN              NaN
# ...                  ...                  ...              ...
# 19853            178.484              121.477          134.450
# 19854            181.759              130.456          147.195
# 19855            171.518              127.628          132.629
# 19856            161.197              118.220          129.901
# 19857            157.643              123.418          135.909
#
#        PRIMARY_ENERGY_CONSUMPTION  SOLAR_CONSUMPTION  WIND_CONSUMPTION
# 19733                         NaN                NaN               NaN
# 19734                         NaN                NaN               NaN
# 19735                         NaN                NaN               NaN
# 19736                         NaN                NaN               NaN
# 19737                         NaN                NaN               NaN
# ...                           ...                ...               ...
# 19853                     600.279              2.556            67.966
# 19854                     633.680              3.712            66.769
# 19855                     621.681              4.823            81.228
# 19856                     599.356              7.556            83.109
# 19857                     610.004             10.110            98.807
#
# [125 rows x 14 columns]

# %%
# Save the filtered columns to a file
df_Sweden.to_csv('sweden_energy_data.csv', index=False)

# %%
print("\n--- MISSING VALUES PER COLUMN ---")
# Shows exactly how many 'NaN' or empty cells are in each column
print(df_Sweden.isnull().sum())
# Out:
# --- MISSING VALUES PER COLUMN ---
# COUNTRY                        0
# YEAR                           0
# POPULATION                     0
# GDP                            2
# BIOFUEL_CONSUMPTION           65
# COAL_CONSUMPTION              65
# FOSSIL_FUEL_CONSUMPTION       65
# GAS_CONSUMPTION               65
# HYDRO_CONSUMPTION             65
# NUCLEAR_CONSUMPTION           65
# OIL_CONSUMPTION               65
# PRIMARY_ENERGY_CONSUMPTION    65
# SOLAR_CONSUMPTION             65
# WIND_CONSUMPTION              65
# dtype: int64

# %%
df_Sweden['GDP'] = df_Sweden['GDP'].interpolate(method='linear')

# %%
print("\n--- MISSING VALUES PER COLUMN ---")
# Shows exactly how many 'NaN' or empty cells are in each column
print(df_Sweden.isnull().sum())
# Out:
# --- MISSING VALUES PER COLUMN ---
# COUNTRY                        0
# YEAR                           0
# POPULATION                     0
# GDP                            0
# BIOFUEL_CONSUMPTION           65
# COAL_CONSUMPTION              65
# FOSSIL_FUEL_CONSUMPTION       65
# GAS_CONSUMPTION               65
# HYDRO_CONSUMPTION             65
# NUCLEAR_CONSUMPTION           65
# OIL_CONSUMPTION               65
# PRIMARY_ENERGY_CONSUMPTION    65
# SOLAR_CONSUMPTION             65
# WIND_CONSUMPTION              65
# dtype: int64

# %%
df_cleaned_rows = df_Sweden.dropna()

# %%
print("\n--- MISSING VALUES PER COLUMN ---")
# Shows exactly how many 'NaN' or empty cells are in each column
print(df_cleaned_rows.isnull().sum())
# Out:
# --- MISSING VALUES PER COLUMN ---
# COUNTRY                       0
# YEAR                          0
# POPULATION                    0
# GDP                           0
# BIOFUEL_CONSUMPTION           0
# COAL_CONSUMPTION              0
# FOSSIL_FUEL_CONSUMPTION       0
# GAS_CONSUMPTION               0
# HYDRO_CONSUMPTION             0
# NUCLEAR_CONSUMPTION           0
# OIL_CONSUMPTION               0
# PRIMARY_ENERGY_CONSUMPTION    0
# SOLAR_CONSUMPTION             0
# WIND_CONSUMPTION              0
# dtype: int64

# %%
# Save the filtered columns to a file
df_cleaned_rows.to_csv('sweden_energy_data2.csv', index=False)

# %%
print("\n--- DUPLICATE ROW COUNT ---")
print("\n--- DUPLICATE ROWS ---")
print(f"Total duplicate rows: {df_cleaned_rows.duplicated().sum()}")
# To see the actual duplicate rows:
# print(df[df_cleaned_rows.duplicated(keep=False)])
# Out:
# --- DUPLICATE ROW COUNT ---
#
# --- DUPLICATE ROWS ---
# Total duplicate rows: 0

# %%
print("\n--- 4. STATISTICAL SUMMARY ---")
# Use this to spot 'Dirty' outliers (like an age of 200 or a negative price)
print(df_cleaned_rows.describe())
# Out:
# --- 4. STATISTICAL SUMMARY ---
#               YEAR    POPULATION           GDP  BIOFUEL_CONSUMPTION  \
# count    60.000000  6.000000e+01  6.000000e+01            60.000000
# mean   1994.500000  8.883785e+06  2.884296e+11             2.754550
# std      17.464249  7.769651e+05  1.112662e+11             4.718644
# min    1965.000000  7.732959e+06  1.333264e+11             0.000000
# 25%    1979.750000  8.306232e+06  1.970232e+11             0.000000
# 50%    1994.500000  8.803200e+06  2.466327e+11             0.000000
# 75%    2009.250000  9.318566e+06  3.905551e+11             3.961000
# max    2024.000000  1.060693e+07  4.942145e+11            17.427000
#
#        COAL_CONSUMPTION  FOSSIL_FUEL_CONSUMPTION  GAS_CONSUMPTION  \
# count         60.000000                60.000000        60.000000
# mean          26.345883               264.489200         5.581283
# std            6.265692                66.386508         4.572569
# min           17.085000               157.322000         0.000000
# 25%           20.944250               223.983500         0.000000
# 50%           24.484500               257.325500         7.884500
# 75%           32.364000               316.435250         9.259500
# max           36.079000               439.693000        15.468000
#
#        HYDRO_CONSUMPTION  NUCLEAR_CONSUMPTION  OIL_CONSUMPTION  \
# count          60.000000            60.000000        60.000000
# mean          170.489333           128.600500       232.562000
# std            24.143666            71.268728        71.545939
# min           115.247000             0.050000       129.901000
# 25%           156.729250            71.698000       180.393250
# 50%           167.784500           158.878000       219.344500
# 75%           189.533250           184.420250       293.018750
# max           218.401000           213.225000       418.846000
#
#        PRIMARY_ENERGY_CONSUMPTION  SOLAR_CONSUMPTION  WIND_CONSUMPTION
# count                   60.000000          60.000000         60.000000
# mean                   609.213017           0.549317         12.376983
# std                     74.737778           1.789615         24.242606
# min                    392.954000           0.000000          0.000000
# 25%                    600.048250           0.000000          0.000000
# 50%                    630.743000           0.003000          0.250000
# 75%                    650.613750           0.019250          7.172500
# max                    716.907000          10.110000         98.807000

# %%
# Select the columns you want to clean
energy_cols = ['BIOFUEL_CONSUMPTION', 'GAS_CONSUMPTION', 'SOLAR_CONSUMPTION', 'WIND_CONSUMPTION']

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_cleaned_rows[energy_cols].quantile(0.25)
Q3 = df_cleaned_rows[energy_cols].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame
# This keeps only rows where values are within the lower and upper bounds
df_cleaned = df_cleaned_rows[~((df_cleaned_rows[energy_cols] < lower_bound) | (df_cleaned_rows[energy_cols] > upper_bound)).any(axis=1)].copy()

print(f"Rows before IQR: {len(df_cleaned_rows)}")
print(f"Rows after IQR: {len(df_cleaned)}")
print(df_cleaned[energy_cols].describe())
# Out:
# Rows before IQR: 60
# Rows after IQR: 47
#        BIOFUEL_CONSUMPTION  GAS_CONSUMPTION  SOLAR_CONSUMPTION  \
# count            47.000000        47.000000          47.000000
# mean              0.560255         4.455021           0.003170
# std               1.270786         4.544744           0.006519
# min               0.000000         0.000000           0.000000
# 25%               0.000000         0.000000           0.000000
# 50%               0.000000         3.229000           0.000000
# 75%               0.000000         8.371000           0.003000
# max               4.671000        15.468000           0.034000
#
#        WIND_CONSUMPTION
# count         47.000000
# mean           1.230170
# std            2.865063
# min            0.000000
# 25%            0.000000
# 50%            0.017000
# 75%            1.131500
# max           15.830000

# %%
print("\n---STATISTICAL SUMMARY ---")
# Use this to spot 'Dirty' outliers (like an age of 200 or a negative price)
print(df_cleaned.describe())
# Out:
# ---STATISTICAL SUMMARY ---
#               YEAR    POPULATION           GDP  BIOFUEL_CONSUMPTION  \
# count    47.000000  4.700000e+01  4.700000e+01            47.000000
# mean   1988.000000  8.543840e+06  2.433581e+11             0.560255
# std      13.711309  4.389992e+05  7.730443e+10             1.270786
# min    1965.000000  7.732959e+06  1.333264e+11             0.000000
# 25%    1976.500000  8.236992e+06  1.861965e+11             0.000000
# 50%    1988.000000  8.436315e+06  2.315584e+11             0.000000
# 75%    1999.500000  8.864852e+06  2.965776e+11             0.000000
# max    2011.000000  9.449207e+06  3.998390e+11             4.671000
#
#        COAL_CONSUMPTION  FOSSIL_FUEL_CONSUMPTION  GAS_CONSUMPTION  \
# count         47.000000                47.000000        47.000000
# mean          27.717298               288.254553         4.455021
# std            6.333181                54.206352         4.544744
# min           17.085000               208.531000         0.000000
# 25%           21.562500               246.421000         0.000000
# 50%           29.838000               275.764000         3.229000
# 75%           32.960000               329.991000         8.371000
# max           36.079000               439.693000        15.468000
#
#        HYDRO_CONSUMPTION  NUCLEAR_CONSUMPTION  OIL_CONSUMPTION  \
# count          47.000000            47.000000        47.000000
# mean          170.860979           123.299872       256.082149
# std            26.208964            79.186305        62.622587
# min           115.247000             0.050000       168.609000
# 25%           152.636000            49.869500       205.219000
# 50%           169.667000           159.211000       235.021000
# 75%           192.970500           191.123500       305.693500
# max           218.401000           213.225000       418.846000
#
#        PRIMARY_ENERGY_CONSUMPTION  SOLAR_CONSUMPTION  WIND_CONSUMPTION
# count                   47.000000          47.000000         47.000000
# mean                   607.242468           0.003170          1.230170
# std                     84.198517           0.006519          2.865063
# min                    392.954000           0.000000          0.000000
# 25%                    559.057500           0.000000          0.000000
# 50%                    641.029000           0.000000          0.017000
# 75%                    665.623000           0.003000          1.131500
# max                    716.907000           0.034000         15.830000

# %%
df_cleaned['BIOFUEL_CONSUMPTION'] = df_cleaned['BIOFUEL_CONSUMPTION'].bfill()
df_cleaned
# Out:
#       COUNTRY  YEAR  POPULATION           GDP  BIOFUEL_CONSUMPTION  \
# 19798  Sweden  1965   7732959.0  1.333264e+11                0.000
# 19799  Sweden  1966   7805532.0  1.361091e+11                0.000
# 19800  Sweden  1967   7866351.0  1.407034e+11                0.000
# 19801  Sweden  1968   7912065.0  1.458023e+11                0.000
# 19802  Sweden  1969   7967962.0  1.531051e+11                0.000
# 19803  Sweden  1970   8042725.0  1.630236e+11                0.000
# 19804  Sweden  1971   8098051.0  1.645514e+11                0.000
# 19805  Sweden  1972   8122375.0  1.683284e+11                0.000
# 19806  Sweden  1973   8137094.0  1.750187e+11                0.000
# 19807  Sweden  1974   8160592.0  1.806192e+11                0.000
# 19808  Sweden  1975   8192612.0  1.852192e+11                0.000
# 19809  Sweden  1976   8222333.0  1.871738e+11                0.000
# 19810  Sweden  1977   8251652.0  1.842012e+11                0.000
# 19811  Sweden  1978   8275740.0  1.874183e+11                0.000
# 19812  Sweden  1979   8293702.0  1.946187e+11                0.000
# 19813  Sweden  1980   8310408.0  1.978528e+11                0.000
# 19814  Sweden  1981   8320408.0  1.978246e+11                0.000
# 19815  Sweden  1982   8325131.0  1.998166e+11                0.000
# 19816  Sweden  1983   8328877.0  2.033276e+11                0.000
# 19817  Sweden  1984   8336441.0  2.114013e+11                0.000
# 19818  Sweden  1985   8350190.0  2.154718e+11                0.000
# 19819  Sweden  1986   8369633.0  2.202063e+11                0.000
# 19820  Sweden  1987   8397600.0  2.268804e+11                0.000
# 19821  Sweden  1988   8436315.0  2.317200e+11                0.000
# 19822  Sweden  1989   8492778.0  2.372350e+11                0.000
# 19823  Sweden  1990   8558526.0  2.402340e+11                0.000
# 19824  Sweden  1991   8616913.0  2.379501e+11                0.000
# 19825  Sweden  1992   8667529.0  2.357568e+11                0.000
# 19826  Sweden  1993   8717989.0  2.315584e+11                0.000
# 19827  Sweden  1994   8780150.0  2.415243e+11                0.000
# 19828  Sweden  1995   8826250.0  2.517411e+11                0.000
# 19829  Sweden  1996   8840281.0  2.564989e+11                0.000
# 19830  Sweden  1997   8845470.0  2.641711e+11                0.000
# 19831  Sweden  1998   8850553.0  2.760407e+11                0.000
# 19832  Sweden  1999   8857642.0  2.897028e+11                0.000
# 19833  Sweden  2000   8872062.0  3.034524e+11                0.000
# 19834  Sweden  2001   8895980.0  3.083981e+11                0.172
# 19835  Sweden  2002   8924991.0  3.174638e+11                0.373
# 19836  Sweden  2003   8958387.0  3.264024e+11                0.771
# 19837  Sweden  2004   8993754.0  3.419012e+11                1.467
# 19838  Sweden  2005   9029713.0  3.544969e+11                1.661
# 19839  Sweden  2006   9080584.0  3.722347e+11                2.270
# 19840  Sweden  2007   9148219.0  3.878818e+11                3.126
# 19841  Sweden  2008   9219853.0  3.889805e+11                3.809
# 19842  Sweden  2009   9298692.0  3.730264e+11                3.916
# 19843  Sweden  2010   9378187.0  3.998390e+11                4.096
# 19844  Sweden  2011   9449207.0  3.976179e+11                4.671
#
#        COAL_CONSUMPTION  FOSSIL_FUEL_CONSUMPTION  GAS_CONSUMPTION  \
# 19798            25.927                  255.630            0.000
# 19799            24.740                  284.397            0.000
# 19800            24.557                  283.337            0.000
# 19801            21.454                  314.164            0.000
# 19802            20.949                  334.464            0.000
# 19803            22.130                  363.272            0.000
# 19804            19.949                  340.756            0.000
# 19805            17.140                  346.425            0.000
# 19806            18.945                  355.537            0.000
# 19807            20.930                  323.249            0.000
# 19808            22.575                  324.060            0.000
# 19809            21.671                  354.098            0.000
# 19810            17.202                  339.532            0.000
# 19811            17.646                  406.708            0.000
# 19812            20.847                  439.693            0.000
# 19813            19.869                  389.495            0.000
# 19814            17.085                  349.543            0.000
# 19815            19.010                  328.078            0.000
# 19816            23.823                  292.482            0.000
# 19817            28.747                  285.453            0.000
# 19818            33.841                  309.777            0.714
# 19819            36.079                  331.904            1.880
# 19820            35.624                  291.923            2.511
# 19821            34.972                  275.764            3.229
# 19822            32.973                  265.510            4.318
# 19823            34.457                  230.102            6.010
# 19824            33.637                  231.322            6.421
# 19825            31.321                  246.283            7.247
# 19826            31.889                  245.129            7.909
# 19827            32.364                  260.109            7.852
# 19828            32.364                  259.021            7.860
# 19829            35.842                  279.286            8.422
# 19830            30.626                  261.309            8.320
# 19831            30.833                  265.919            8.246
# 19832            29.473                  260.699            8.264
# 19833            29.838                  242.340            8.082
# 19834            32.334                  246.559            9.118
# 19835            34.722                  249.531            9.279
# 19836            34.043                  249.210            9.253
# 19837            35.025                  248.317            9.212
# 19838            32.015                  237.690            8.777
# 19839            35.350                  240.173            9.189
# 19840            32.938                  233.711            9.483
# 19841            32.947                  229.168            8.610
# 19842            23.227                  209.489           11.495
# 19843            31.078                  228.815           15.468
# 19844            27.705                  208.531           12.217
#
#        HYDRO_CONSUMPTION  NUCLEAR_CONSUMPTION  OIL_CONSUMPTION  \
# 19798            128.953                0.050          229.703
# 19799            126.358                0.125          259.657
# 19800            136.906                0.139          258.780
# 19801            135.386                0.064          292.710
# 19802            116.194                0.169          313.515
# 19803            115.247                0.156          341.142
# 19804            144.478                0.250          320.807
# 19805            149.286                4.069          329.285
# 19806            166.311                5.864          336.592
# 19807            159.069                5.706          302.319
# 19808            160.133               33.247          301.485
# 19809            152.311               44.425          332.426
# 19810            148.597               55.314          322.331
# 19811            160.425               66.058          389.062
# 19812            169.667               58.442          418.846
# 19813            163.522               73.578          369.626
# 19814            165.981              104.664          332.458
# 19815            152.961              108.458          309.068
# 19816            176.511              113.900          268.659
# 19817            188.628              141.461          256.706
# 19818            197.189              162.669          275.222
# 19819            169.258              194.308          293.945
# 19820            199.594              187.181          253.788
# 19821            194.119              192.844          237.564
# 19822            199.306              182.231          228.219
# 19823            201.414              189.403          189.635
# 19824            175.692              213.225          191.265
# 19825            206.567              176.511          207.715
# 19826            207.353              170.542          205.331
# 19827            164.158              203.211          219.892
# 19828            189.156              194.264          218.797
# 19829            143.722              206.317          235.021
# 19830            191.822              194.244          222.363
# 19831            207.619              204.397          226.840
# 19832            199.142              203.300          222.962
# 19833            218.289              159.211          204.420
# 19834            218.401              199.196          205.107
# 19835            181.803              186.605          205.530
# 19836            145.886              183.692          205.914
# 19837            164.195              210.491          204.079
# 19838            194.633              195.405          196.897
# 19839            164.748              179.083          195.634
# 19840            175.983              178.110          191.290
# 19841            182.796              168.573          187.610
# 19842            172.020              136.937          174.766
# 19843            174.937              150.333          182.269
# 19844            173.740              156.672          168.609
#
#        PRIMARY_ENERGY_CONSUMPTION  SOLAR_CONSUMPTION  WIND_CONSUMPTION
# 19798                     392.954              0.000             0.000
# 19799                     419.035              0.000             0.000
# 19800                     429.217              0.000             0.000
# 19801                     458.350              0.000             0.000
# 19802                     458.328              0.000             0.000
# 19803                     486.529              0.000             0.000
# 19804                     495.322              0.000             0.000
# 19805                     510.221              0.000             0.000
# 19806                     539.842              0.000             0.000
# 19807                     499.548              0.000             0.000
# 19808                     529.476              0.000             0.000
# 19809                     562.746              0.000             0.000
# 19810                     555.369              0.000             0.000
# 19811                     645.843              0.000             0.000
# 19812                     681.112              0.000             0.000
# 19813                     641.029              0.000             0.000
# 19814                     636.087              0.000             0.000
# 19815                     604.897              0.000             0.000
# 19816                     601.358              0.000             0.008
# 19817                     636.668              0.000             0.014
# 19818                     691.626              0.000             0.017
# 19819                     716.907              0.000             0.017
# 19820                     701.871              0.000             0.017
# 19821                     685.929              0.000             0.014
# 19822                     670.826              0.000             0.014
# 19823                     644.207              0.000             0.017
# 19824                     642.135              0.000             0.036
# 19825                     652.992              0.000             0.086
# 19826                     647.156              0.003             0.144
# 19827                     649.779              0.003             0.208
# 19828                     666.649              0.003             0.292
# 19829                     650.224              0.003             0.400
# 19830                     673.384              0.003             0.564
# 19831                     705.514              0.003             0.856
# 19832                     690.032              0.003             0.994
# 19833                     651.783              0.003             1.269
# 19834                     695.756              0.006             1.331
# 19835                     649.472              0.005             1.666
# 19836                     609.237              0.005             1.850
# 19837                     664.597              0.005             2.304
# 19838                     673.010              0.005             2.525
# 19839                     630.143              0.005             2.642
# 19840                     641.107              0.008             3.808
# 19841                     638.565              0.011             5.279
# 19842                     579.813              0.018             6.537
# 19843                     621.735              0.023             9.079
# 19844                     612.016              0.034            15.830

# %%
df = df_cleaned.reset_index(drop=True)

# %%
numeric_df = df.drop(columns=['COUNTRY']) 

# 2. Calculate the Correlation Matrix
# This results in values between -1 (inverse) and 1 (perfect correlation)
corr_matrix = numeric_df.corr()

# 3. Create the Correlation Heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Correlation Heatmap: Energy, Economy, and Population')
plt.show()

# %%
# Data extracted from the heatmap for YEAR row/column
# Variables: YEAR, POPULATION, GDP, BIOFUEL, COAL, FOSSIL_FUEL, GAS, HYDRO, NUCLEAR, OIL, PRIMARY_ENERGY, SOLAR, WIND
# Correlation values with YEAR:
correlations = {
    'BIOFUEL_CONSUMPTION': 0.66,
    'COAL_CONSUMPTION': 0.68,
    'FOSSIL_FUEL_CONSUMPTION': -0.72,
    'GAS_CONSUMPTION': 0.93,
    'HYDRO_CONSUMPTION': 0.60,
    'NUCLEAR_CONSUMPTION': 0.84,
    'OIL_CONSUMPTION': -0.76,
    'PRIMARY_ENERGY_CONSUMPTION': 0.69,
    'SOLAR_CONSUMPTION': 0.66,
    'WIND_CONSUMPTION': 0.62
}

df_corr = pd.DataFrame(list(correlations.items()), columns=['Variable', 'Correlation_with_Year'])
df_corr = df_corr.sort_values(by='Correlation_with_Year', ascending=False)
print(df_corr)
# Out:
#                      Variable  Correlation_with_Year
# 3             GAS_CONSUMPTION                   0.93
# 5         NUCLEAR_CONSUMPTION                   0.84
# 7  PRIMARY_ENERGY_CONSUMPTION                   0.69
# 1            COAL_CONSUMPTION                   0.68
# 0         BIOFUEL_CONSUMPTION                   0.66
# 8           SOLAR_CONSUMPTION                   0.66
# 9            WIND_CONSUMPTION                   0.62
# 4           HYDRO_CONSUMPTION                   0.60
# 2     FOSSIL_FUEL_CONSUMPTION                  -0.72
# 6             OIL_CONSUMPTION                  -0.76

# %%
# 1. Data (Ensured both lists have 10 items)
data = {
    'Variable': [
        'GAS_CONSUMPTION', 'NUCLEAR_CONSUMPTION', 'PRIMARY_ENERGY_CONSUMPTION',
        'COAL_CONSUMPTION', 'BIOFUEL_CONSUMPTION', 'SOLAR_CONSUMPTION',
        'WIND_CONSUMPTION', 'HYDRO_CONSUMPTION', 'FOSSIL_FUEL_CONSUMPTION',
        'OIL_CONSUMPTION'
    ],
    'Correlation': [
        0.93, 0.84, 0.69, 0.68, 0.66, 0.66, 0.62, 0.60, -0.72, -0.76
    ]
}

df = pd.DataFrame(data).sort_values(by='Correlation', ascending=False)

# 2. Set the visual style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 8))

# 3. Create colors based on value
colors = ['#4c72b0' if x >= 0 else '#c44e52' for x in df['Correlation']]

# 4. Plot (added 'hue' to avoid modern Seaborn warnings)
ax = sns.barplot(data=df, x='Correlation', y='Variable', palette=colors, hue='Variable', legend=False)

# 5. Customize the graph
plt.axvline(0, color='black', lw=1)
plt.title('Correlation of Variables with YEAR', fontsize=16, pad=20)
plt.xlabel('Correlation Coefficient (r)', fontsize=12)
plt.ylabel('')
plt.xlim(-1.1, 1.1) # Expanded slightly so labels don't get cut off

# Add value labels
for i, v in enumerate(df['Correlation']):
    # Logic to place text outside positive bars or inside/outside negative bars
    x_pos = v + 0.02 if v >= 0 else v - 0.12
    ax.text(x_pos, i, f'{v:.2f}', color='black', va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 1. Variables to compare
cols_to_plot = [
    'GAS_CONSUMPTION', 'NUCLEAR_CONSUMPTION', 'PRIMARY_ENERGY_CONSUMPTION',  
]

# 2. Pairplot
# Height and aspect control the size of each individual subplot
grid = sns.pairplot(df_cleaned, 
                    y_vars=['YEAR'], 
                    x_vars=cols_to_plot,
                    kind='reg',
                    height=4, 
                    aspect=1.2,
                    plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.5}})

# 3. Add a title and adjust layout
# y=1.05 moves the title up slightly so it doesn't hit the charts
grid.fig.suptitle("Visualising High Correlations with YEAR", y=1.05, fontsize=16)

# Rotate labels AND align them to the right so they point to the correct tick
for ax in grid.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# Add padding so labels don't get cut off at the bottom
plt.tight_layout()
plt.show()
